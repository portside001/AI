# %%
# pip install gTTS

# %%
from gtts import gTTS
from IPython.display import Audio
text_to_speech = gTTS(
    """
    welcome to data my profile my self jarvius
    """,lang='hi',tld='com'
)

text_to_speech.save('text_to_speech_gtts.wav')
sound_file = text_to_speech_gtts.wav
Audio(sound_file,autoplay=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 10
#       3 text_to_speech_gtts = gTTS(
#       4     """
#       5     welcome to data my profile my self jarvius
#       6     """,lang='hi',tld='com'
#       7 )
#       9 text_to_speech.save('text_to_speech_gtts.wav')
# ---> 10 sound_file = text_to_speech_gtts.wav
#      11 Audio(sound_file,autoplay=False)
#
# AttributeError: 'gTTS' object has no attribute 'wav'
