# %%
import os
import nltk
# nltk.download() # after download we need to comment nltk.downloda() we do not need to download again

# %%
import nltk.corpus

# %%
AI = '''Artificial Intelligence refers to the intelligence of machines. This is in contrast to the natural intelligence of
humans and animals. With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and
problem-solving. Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.
It is probably the fastest-growing development in the World of technology and innovation. Furthermore, many experts believe
AI could solve major challenges and crisis situations.'''

# %%
AI
# Out:
# 'Artificial Intelligence refers to the intelligence of machines. This is in contrast to the natural intelligence of\nhumans and animals. With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and\nproblem-solving. Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.\nIt is probably the fastest-growing development in the World of technology and innovation. Furthermore, many experts believe\nAI could solve major challenges and crisis situations.'

# %%
type(AI)
# Out:
# str

# %%
from nltk.tokenize import word_tokenize

# %%
AI_tokens = word_tokenize(AI)

# %%
AI_tokens
# Out:
# ['Artificial',
#  'Intelligence',
#  'refers',
#  'to',
#  'the',
#  'intelligence',
#  'of',
#  'machines',
#  '.',
#  'This',
#  'is',
#  'in',
#  'contrast',
#  'to',
#  'the',
#  'natural',
#  'intelligence',
#  'of',
#  'humans',
#  'and',
#  'animals',
#  '.',
#  'With',
#  'Artificial',
#  'Intelligence',
#  ',',
#  'machines',
#  'perform',
#  'functions',
#  'such',
#  'as',
#  'learning',
#  ',',
#  'planning',
#  ',',
#  'reasoning',
#  'and',
#  'problem-solving',
#  '.',
#  'Most',
#  'noteworthy',
#  ',',
#  'Artificial',
#  'Intelligence',
#  'is',
#  'the',
#  'simulation',
#  'of',
#  'human',
#  'intelligence',
#  'by',
#  'machines',
#  '.',
#  'It',
#  'is',
#  'probably',
#  'the',
#  'fastest-growing',
#  'development',
#  'in',
#  'the',
#  'World',
#  'of',
#  'technology',
#  'and',
#  'innovation',
#  '.',
#  'Furthermore',
#  ',',
#  'many',
#  'experts',
#  'believe',
#  'AI',
#  'could',
#  'solve',
#  'major',
#  'challenges',
#  'and',
#  'crisis',
# ...

# %%
len(AI_tokens)
# Out:
# 81

# %%
from nltk.tokenize import sent_tokenize

# %%
AI_sent = sent_tokenize(AI)
AI_sent
# Out:
# ['Artificial Intelligence refers to the intelligence of machines.',
#  'This is in contrast to the natural intelligence of\nhumans and animals.',
#  'With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and\nproblem-solving.',
#  'Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.',
#  'It is probably the fastest-growing development in the World of technology and innovation.',
#  'Furthermore, many experts believe\nAI could solve major challenges and crisis situations.']

# %%
len(AI_sent)
# Out:
# 6

# %%
AI
# Out:
# 'Artificial Intelligence refers to the intelligence of machines. This is in contrast to the natural intelligence of\nhumans and animals. With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and\nproblem-solving. Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.\nIt is probably the fastest-growing development in the World of technology and innovation. Furthermore, many experts believe\nAI could solve major challenges and crisis situations.'

# %%
from nltk.tokenize import blankline_tokenize #gave how many paragraph 
AI_blank = blankline_tokenize(AI)
AI_blank
# Out:
# ['Artificial Intelligence refers to the intelligence of machines. This is in contrast to the natural intelligence of\nhumans and animals. With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and\nproblem-solving. Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.\nIt is probably the fastest-growing development in the World of technology and innovation. Furthermore, many experts believe\nAI could solve major challenges and crisis situations.']

# %%
len(AI_blank)
# Out:
# 1

# %%
from nltk.tokenize import WhitespaceTokenizer
WT_Token = WhitespaceTokenizer().tokenize(AI)
WT_Token
# Out:
# ['Artificial',
#  'Intelligence',
#  'refers',
#  'to',
#  'the',
#  'intelligence',
#  'of',
#  'machines.',
#  'This',
#  'is',
#  'in',
#  'contrast',
#  'to',
#  'the',
#  'natural',
#  'intelligence',
#  'of',
#  'humans',
#  'and',
#  'animals.',
#  'With',
#  'Artificial',
#  'Intelligence,',
#  'machines',
#  'perform',
#  'functions',
#  'such',
#  'as',
#  'learning,',
#  'planning,',
#  'reasoning',
#  'and',
#  'problem-solving.',
#  'Most',
#  'noteworthy,',
#  'Artificial',
#  'Intelligence',
#  'is',
#  'the',
#  'simulation',
#  'of',
#  'human',
#  'intelligence',
#  'by',
#  'machines.',
#  'It',
#  'is',
#  'probably',
#  'the',
#  'fastest-growing',
#  'development',
#  'in',
#  'the',
#  'World',
#  'of',
#  'technology',
#  'and',
#  'innovation.',
#  'Furthermore,',
#  'many',
#  'experts',
#  'believe',
#  'AI',
#  'could',
#  'solve',
#  'major',
#  'challenges',
#  'and',
#  'crisis',
#  'situations.']

# %%
len(WT_Token)
# Out:
# 70

# %%
s = 'good apple cost $3.88 in hydrabad please buy two of them thanks'
s
# Out:
# 'good apple cost $3.88 in hydrabad please buy two of them thanks'

# %%
type(s)
# Out:
# str

# %%
from nltk.tokenize import wordpunct_tokenize
wp = wordpunct_tokenize(s)
wp
# Out:
# ['good',
#  'apple',
#  'cost',
#  '$',
#  '3',
#  '.',
#  '88',
#  'in',
#  'hydrabad',
#  'please',
#  'buy',
#  'two',
#  'of',
#  'them',
#  'thanks']

# %%
len(wp)
# Out:
# 15

# %%
string ="hello this is me and how about  you llm gen ai agentic ai"
from nltk.util import bigrams,trigrams,ngrams
qoutes = nltk.word_tokenize(string)

# %%
qoutes
# Out:
# ['hello',
#  'this',
#  'is',
#  'me',
#  'and',
#  'how',
#  'about',
#  'you',
#  'llm',
#  'gen',
#  'ai',
#  'agentic',
#  'ai']

# %%
qoutes_bigrams = list(nltk.bigrams(qoutes))

# %%
qoutes_bigrams
# Out:
# [('hello', 'this'),
#  ('this', 'is'),
#  ('is', 'me'),
#  ('me', 'and'),
#  ('and', 'how'),
#  ('how', 'about'),
#  ('about', 'you'),
#  ('you', 'llm'),
#  ('llm', 'gen'),
#  ('gen', 'ai'),
#  ('ai', 'agentic'),
#  ('agentic', 'ai')]

# %%
qoutes_trigrams = list(nltk.trigrams(qoutes))
qoutes_trigrams
# Out:
# [('hello', 'this', 'is'),
#  ('this', 'is', 'me'),
#  ('is', 'me', 'and'),
#  ('me', 'and', 'how'),
#  ('and', 'how', 'about'),
#  ('how', 'about', 'you'),
#  ('about', 'you', 'llm'),
#  ('you', 'llm', 'gen'),
#  ('llm', 'gen', 'ai'),
#  ('gen', 'ai', 'agentic'),
#  ('ai', 'agentic', 'ai')]

# %%
qoutes_ngrams = list(nltk.ngrams(qoutes))
qoutes_ngrams
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 qoutes_ngrams = list(nltk.ngrams(qoutes))
#       2 qoutes_ngrams
#
# TypeError: ngrams() missing 1 required positional argument: 'n'

# %%
qoutes_ngrams = list(nltk.ngrams(qoutes,4))
qoutes_ngrams

# %%
from nltk.stem import PorterStemmer
pst = PorterStemmer()

# %%
pst.stem('affection')

# %%
pst.stem('playing')

# %%
pst.stem('played')

# %%
pst.stem('maximum')

# %%
from nltk.stem import PorterStemmer

pst = PorterStemmer()

words_of_stem = ['give', 'giving', 'give', 'gaved', 'thinking', 'loving', 'maximum', 'sachin']

for words in words_of_stem:
    print(words + ' : ' + pst.stem(words))

# %%
from nltk.stem import LancasterStemmer
lst = LancasterStemmer()
words_of_stem = ['give','giving','give','gaved','thinking','loving','maximum','sachin']

for words in words_of_stem:
    print(words+ ' : ' + lst.stem(words))

# %%
from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer
word_lem = WordNetLemmatizer()

# %%
word_lem

# %%
from nltk.corpus import stopwords

# %%
len(stopwords.words('english'))

# %%
len(stopwords.words('hindi'))

# %%
sent = "my name is sachin rajput"
sent_tokens = word_tokenize(sent)
sent_tokens

# %%
for token in sent_tokens:
    print(nltk.pos_tags([token]))

# %% [markdown]
# # NLU

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
text = ("math is a good subject we can use this in python")

# %%
wordcloud = WordCloud(width=420,height=200,margin=2 , background_color='black',
                     colormap='Accent',mode='RGBA'
                     ).generate(text)

# %%
plt.imshow(wordcloud,interpolation='quadric')
plt.axis('off')
plt.margins(x=0,y=0)
plt.show()
